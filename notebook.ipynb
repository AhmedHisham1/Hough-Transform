# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from utils import hough_transform

# %matplotlib inline

# %%
img = cv2.imread('test_image.png')
img = cv2.resize(img, (100,100), interpolation=cv2.INTER_AREA)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, binary_img = cv2.threshold(gray, 150, 1, cv2.THRESH_BINARY)
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(binary_img, cmap='gray')
A = hough_transform(binary_img)
plt.subplot(1,2,2)
plt.imshow(A)

# %%
img = cv2.imread('test_image2.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, binary_img2 = cv2.threshold(gray, 150, 1, cv2.THRESH_BINARY)
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(binary_img2, cmap='gray')
A2 = hough_transform(binary_img2)
plt.subplot(1,2,2)
plt.imshow(A2)

# %%
img = cv2.imread('stripes.jpg')
img = cv2.resize(img, (100,100), interpolation=cv2.INTER_AREA)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, binary_img3 = cv2.threshold(gray, 150, 1, cv2.THRESH_BINARY)
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(binary_img3, cmap='gray')
A3 = hough_transform(binary_img3)
plt.subplot(1,2,2)
plt.imshow(A3)

# %%
img = cv2.imread('brain_MR.jpg')
img = cv2.resize(img, (100,100), interpolation=cv2.INTER_AREA)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.Canny(gray, 120,200)
_, binary_img4 = cv2.threshold(gray, 150, 1, cv2.THRESH_BINARY)
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(binary_img4, cmap='gray')
A4 = hough_transform(binary_img4)
plt.subplot(1,2,2)
plt.imshow(A4)

# %%
img = cv2.imread('test_image3.png')
img = cv2.resize(img, (100,100), interpolation=cv2.INTER_AREA)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.Canny(img, 100,150)
_, binary_img5 = cv2.threshold(gray, 150, 1, cv2.THRESH_BINARY)
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(binary_img5, cmap='gray')
A5 = hough_transform(binary_img5)
plt.subplot(1,2,2)
plt.imshow(A5)
